# %% [markdown]
# 作業目標:<br>
# 1. 敘述統計量計算<br>
# 2. 運用自定義函數apply

# %% [markdown]
# 作業重點:<br>
# 1. 了解敘述統計量並解釋<br>
# 2. 運用apply時須注意自定義函數寫法

# %% [markdown]
# 題目<br>
# 對以下成績資料做分析<br>
# 1. 6號學生(student_id=6)3科平均分數為何?<br>
# 2. 6號學生3科平均分數是否有贏過班上一半的同學?<br>
# 3. 由於班上同學成績不好，所以學校統一加分，加分方式為開根號乘以十，請問6號同學3科成績分別是?<br>
# 4. 承上題，加分後各科班平均變多少?
# <br>
# score_df = pd.DataFrame([[1,56,66,70],
#               [2,90,45,34],
#               [3,45,32,55],
#               [4,70,77,89],
#               [5,56,80,70],
#               [6,60,54,55],
#               [7,45,70,79],
#               [8,34,77,76],
#               [9,25,87,60],
#               [10,88,40,43]],columns=['student_id','math_score','english_score','chinese_score'])

# %%
import pandas as pd
import numpy as np
import math
score_df = pd.DataFrame([[1,56,66,70], 
              [2,90,45,34],
              [3,45,32,55],
              [4,70,77,89],
              [5,56,80,70],
              [6,60,54,55],
              [7,45,70,79],
              [8,34,77,76],
              [9,25,87,60],
              [10,88,40,43]],columns=['student_id','math_score','english_score','chinese_score'])
score_df = score_df.set_index('student_id')
score_df
# Out:
#             math_score  english_score  chinese_score
# student_id
# 1                   56             66             70
# 2                   90             45             34
# 3                   45             32             55
# 4                   70             77             89
# 5                   56             80             70
# 6                   60             54             55
# 7                   45             70             79
# 8                   34             77             76
# 9                   25             87             60
# 10                  88             40             43

# %%
#1.6號學生(student_id=6)3科平均分數為何?
mean_6 = score_df[5:6].mean(axis=1).mean()
mean_6
# Out:
# 56.333333333333336

# %%
#2. 6號學生3科平均分數是否有贏過班上一半的同學
overall_mean = score_df.mean(axis=1).mean()
if mean_6 > overall_mean:
  print('yes');
else: 
  print('no');
# Out:
# no

# %%
#由於班上同學成績不好，所以學校統一加分，加分方式為開根號乘以十，請問6號同學3科成績分別是?
score_plus = score_df.apply(lambda x : np.sqrt(x)*10)
score_plus[5:6]
# Out:
#             math_score  english_score  chinese_score
# student_id
# 6            77.459667      73.484692      74.161985

# %%
#承上題，加分後各科班平均變多少

# %%
score_plus.mean()
# Out:
# math_score       74.194221
# english_score    78.350301
# chinese_score    78.739928
# dtype: float64

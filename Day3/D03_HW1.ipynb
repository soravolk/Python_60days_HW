# %% [markdown]
# # [作業目標]
#
# 1. [簡答題] 請比較 np.zeros 和 np.empty 產生出來的陣列有何差異？為什麼要設計兩種方法？
#
# ```
# print(np.zeros((2, 3)))
# print(np.empty((2, 3)))
# ```
#
# 2. 在不用「整數亂數方法」的限制下，如何將包含小數的轉換整數？請將給定的 a 陣列當中的元素變成去掉小數變成整數。
# 3. 承上題，怎樣可以限制整數的範圍介於 m - n 之間？請將給定的 a 陣列當中的元素的範圍調整成 m - n 之間。

# %% [markdown]
# # 作業

# %% [markdown]
# ### 1. [簡答題] 請比較 np.zeros 和 np.empty 產生出來的陣列有何差異？為什麼要設計兩種方法？
#
# ```
# print(np.zeros((2, 3)))
# print(np.empty((2, 3)))
# ```

# %% [markdown]
# np.zeros會建立元素全為0的陣列，np.empty則是建立隨機給定的元素。依照使用情境能供不同需求來使用。

# %% [markdown]
# ### 2. 在不用「整數亂數方法」的限制下，如何將包含小數的轉換整數？請將給定的 a 陣列當中的元素變成去掉小數變成整數。

# %%
import numpy as np

# %%
# 參考解答

a = np.random.rand(2, 3)
b = a // 1
b
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# ### 3. 承上題，怎樣可以限制整數的範圍介於 m - n 之間？請將給定的 a 陣列當中的元素的範圍調整成 m - n 之間。

# %%
m = 20
n = 40

c = abs((a - b)) * (n - m)
ans = c + m
ans
# Out:
# array([[28.72747228, 29.0796291 , 38.4384874 ],
#        [28.29503989, 34.94817314, 35.32369828]])

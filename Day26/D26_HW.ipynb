# %% [markdown]
# # 作業: 處理分類數據
#
# 1.建立簡單的水果資料集
# fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
# counts = [5, 3, 4, 2, 4, 6]
#
# 2. 利用vbar
# 水果名稱因子列表作為x 坐標，將條形高度作為top坐標，以及可選地width我們想要設置的任何屬性進行調用：
#
# p.vbar(x=fruits, top=[5, 3, 4, 2, 4, 6], width=0.9)
#
# 3. 由於Bokeh會按順序顯示條形，因此在條形圖中“排序”條形與對范圍的因子進行排序相同。
#
# sorted_fruits = sorted(fruits, key=lambda x: counts[fruits.index(x)])

# %%
import bokeh.io
from bokeh.resources import INLINE
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, CustomJS, Slider
from bokeh.plotting import figure, output_file, show, output_notebook
#from bokeh.sampledata.stocks import AAPL, GOOG, IBM, MSFT
import pandas as pd

# 環境 settings
bokeh.io.reset_output()
bokeh.io.output_notebook(INLINE)

# %%
#指定輸出檔名
output_file("out.html")

#給定資料
fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

# 不增設按鈕 toolbar_location=None, tools=""
# plot_height 設定條形高度
#配置圖表
p = figure(x_range=fruits, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, bottom=0, width=0.5, fill_color="#b3de69")

#Y座標從0開始
p.y_range.start = 0

show(p)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#指定輸出檔名
output_file("out2.html")

#資料做排序
fruits = sorted(fruits, key=lambda x : counts[fruits.index(x)])
counts.sort()

# 不增設按鈕 toolbar_location=None, tools=""
# plot_height 設定條形高度
# 配置圖表
p = figure(x_range=fruits, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x=fruits, top=counts, bottom=0, width=0.5, fill_color="#b3de69")

#Y座標從0開始
p.y_range.start = 0

show(p)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
